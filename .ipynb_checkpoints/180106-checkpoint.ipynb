# %%
def add(*args):
    total = str()
    for arg in args:
        total=total+str(arg)
    return total

add(1,2,3,4,5)
add("1","2","int")
# Out:
# '12int'

# %%
total=str()
total=total+'3'
total
# Out:
# '3'

# %%
def add(x,y,z):
    n=x+y+z
    return n

xlist=(1,2,3)
ylist=(4,5,6)
zlist=(7,8,9)

suma=map(add,xlist,ylist,zlist)

print(suma)
# Out:
# <map object at 0x000002AD6CC37F28>

# %%
total=list()
total.extend([1,2,3,4])
total
# Out:
# [1, 2, 3, 4]

# %%
# %%writefile ex1.py
PI = 3.1416

def sum(lst):
    tot = lst[0]
    for value in lst[1:]:
        tot = tot + value
    return tot
    
w = [0, 1, 2, 3]
print(sum(w), PI)
# Out:
# Overwriting ex1.py

# %%
# %run ex1.py
# Out:
# 6 3.1416

# %%
import ex1
sum([2,3,4,5])
# Out:
# 14

# %%
# %%writefile ex2.py

PI = 3.1416

def sum(lst):
    """ Sum the values in a list
    """
    tot = 0
    for value in lst:
        tot = tot + value
    return tot

def add2(x, y):
    " Add two values."
    a = x + y
    return a

def test():
    w = [0,1,2,3]
    assert(sum(w) == 6)
    print('test passed.')
    
if __name__ == '__main__':
    test()
# Out:
# Overwriting ex2.py

# %%
import ex2
sum([2,3,4,5])
add2(2,3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-a9317cf5a3b2> in <module>()
#       1 import ex2
#       2 sum([2,3,4,5])
# ----> 3 add2(2,3)
#
# NameError: name 'add2' is not defined

# %%
    try:
        y=2/x
        print(x)
    except ValueError:
        print('0 is not valid')

# %%
x=int(input('>'))
print(x)
